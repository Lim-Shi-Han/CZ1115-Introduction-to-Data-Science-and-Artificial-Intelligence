# %% [markdown]
# # Exercise 4

# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %% [markdown]
# ## Question 1

# %%
#a) Plot SalePrice against GrLivArea using any appropriate bivariate plot to note the strong linear relationship.

houseData = pd.read_csv('train.csv')

salePrice = pd.DataFrame(houseData['SalePrice'])
grLivArea = pd.DataFrame(houseData['GrLivArea']) 

# Create a joint dataframe by concatenating the two variables
trainDF = pd.concat([grLivArea, salePrice], axis = 1).reindex(grLivArea.index)

# Jointplot of Total Train against HP Train
sb.jointplot(data = trainDF, x = "GrLivArea", y = "SalePrice", height = 12)

# %%
#b) Print the correlation coefficient between these two variables to get a numerical evidence of the relationship.
print(trainDF.corr())
# Out:
#             GarageArea  SalePrice
# GarageArea    1.000000   0.623431
# SalePrice     0.623431   1.000000

# %%
#c) Import Linear Regression model from Scikit-Learn : from sklearn.linear_model import LinearRegression

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
#d) Partition the dataset houseData into two “random” portions : Train Data (1100 rows) and Test Data (360 rows).

# Split the Dataset into Train and Test
g_train, g_test, s_train, s_test = train_test_split(grLivArea, salePrice, test_size = 360)

# %%
#e) Training : Fit a Linear Regression model on the Train Dataset to predict or estimate SalePrice using GrLivArea.

# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(g_train, s_train)        # train the linear regression model

# Predict SalePrice values corresponding to GrLivArea
s_train_pred = linreg.predict(g_train)
s_test_pred = linreg.predict(g_test)

# %%
#f) Print the coefficients of the Linear Regression model you just fit, and plot the regression line on a scatterplot.

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)

# Plot the Linear Regression line
f = plt.figure(figsize=(16, 8))
plt.scatter(g_train, s_train)
plt.scatter(g_train, s_train_pred, color = "r")
plt.show()
# Out:
# Intercept of Regression 	: b =  [25994.79373659]
# Coefficients of Regression 	: a =  [[102.33521469]]

# %%
#g) Print Explained Variance (R^2) and Mean Squared Error (MSE) on Train Data to check Goodness of Fit of model.

# Explained Variance (R^2)
print("Explained Variance (R^2) \t:", linreg.score(g_train, s_train))

# Mean Squared Error (MSE)
def mean_sq_err(actual, predicted):
    '''Returns the Mean Squared Error of actual and predicted values'''
    return np.mean(np.square(np.array(actual) - np.array(predicted)))


mse = mean_sq_err(s_train, s_train_pred)
print("Mean Squared Error (MSE) \t:", mse)
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mse))
# Out:
# Explained Variance (R^2) 	: 0.47497310599547227
# Mean Squared Error (MSE) 	: 3172506925.958503
# Root Mean Squared Error (RMSE) 	: 56325.01154867616

# %%
#h) Predict SalePrice in case of Test Data using the Linear Regression model and the predictor variable GrLivArea

# Predict SalePrice values corresponding to GrLivArea
s_test_pred = linreg.predict(g_test)

# %%
#i) Plot the predictions on a Scatterplot of GrLivArea and SalePrice in the Test Data to visualize model accuracy.

# Plot the Predictions
f = plt.figure(figsize=(16, 8))
plt.scatter(g_test, s_test, color = "green")
plt.scatter(g_test, s_test_pred, color = "red")
plt.show()

# %%
#j) Print the Mean Squared Error (MSE) on Test Data to check Goodness of Fit of model, compared to the Training.

# Explained Variance (R^2)
print("Explained Variance (R^2) \t:", linreg.score(g_test, s_test))

mse = mean_sq_err(s_test, s_test_pred)
print("Mean Squared Error (MSE) \t:", mse)
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mse))
# Out:
# Explained Variance (R^2) 	: 0.5683922489155996
# Mean Squared Error (MSE) 	: 3065871551.078914
# Root Mean Squared Error (RMSE) 	: 55370.31290392817

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### LotArea

# %%
#a) Plot SalePrice against LotArea using any appropriate bivariate plot to note the strong linear relationship.

houseData = pd.read_csv('train.csv')

salePrice = pd.DataFrame(houseData['SalePrice'])
lotArea = pd.DataFrame(houseData['LotArea']) 

# Create a joint dataframe by concatenating the two variables
trainDF = pd.concat([lotArea, salePrice], axis = 1).reindex(lotArea.index)

# Jointplot of Total Train against HP Train
sb.jointplot(data = trainDF, x = "LotArea", y = "SalePrice", height = 12)

# %%
#b) Print the correlation coefficient between these two variables to get a numerical evidence of the relationship.
print(trainDF.corr())
# Out:
#             LotArea  SalePrice
# LotArea    1.000000   0.263843
# SalePrice  0.263843   1.000000

# %%
#d) Partition the dataset houseData into two “random” portions : Train Data (1100 rows) and Test Data (360 rows).

# Split the Dataset into Train and Test
l_train, l_test, s_train, s_test = train_test_split(lotArea, salePrice, test_size = 360)

# %%
#e) Training : Fit a Linear Regression model on the Train Dataset to predict or estimate SalePrice using LotArea.

# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(l_train, s_train)        # train the linear regression model

# Predict SalePrice values corresponding to LotArea
s_train_pred = linreg.predict(l_train)
s_test_pred = linreg.predict(l_test)

# %%
#f) Print the coefficients of the Linear Regression model you just fit, and plot the regression line on a scatterplot.

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)

# Plot the Linear Regression line
f = plt.figure(figsize=(16, 8))
plt.scatter(l_train, s_train)
plt.scatter(l_train, s_train_pred, color = "r")
plt.show()
# Out:
# Intercept of Regression 	: b =  [161071.73217614]
# Coefficients of Regression 	: a =  [[1.7610498]]

# %%
#g) Print Explained Variance (R^2) and Mean Squared Error (MSE) on Train Data to check Goodness of Fit of model.

# Explained Variance (R^2)
print("Explained Variance (R^2) \t:", linreg.score(l_train, s_train))

mse = mean_sq_err(s_train, s_train_pred)
print("Mean Squared Error (MSE) \t:", mse)
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mse))
# Out:
# Explained Variance (R^2) 	: 0.06356376152852328
# Mean Squared Error (MSE) 	: 5653077477.198197
# Root Mean Squared Error (RMSE) 	: 75186.95017885881

# %%
#h) Predict SalePrice in case of Test Data using the Linear Regression model and the predictor variable LotArea

# Predict SalePrice values corresponding to LotArea
s_test_pred = linreg.predict(l_test)

# %%
#i) Plot the predictions on a Scatterplot of LotArea and SalePrice in the Test Data to visualize model accuracy.

# Plot the Predictions
f = plt.figure(figsize=(16, 8))
plt.scatter(l_test, s_test, color = "green")
plt.scatter(l_test, s_test_pred, color = "red")
plt.show()

# %%
#j) Print the Mean Squared Error (MSE) on Test Data to check Goodness of Fit of model, compared to the Training.

# Explained Variance (R^2)
print("Explained Variance (R^2) \t:", linreg.score(l_test, s_test))

mse = mean_sq_err(s_test, s_test_pred)
print("Mean Squared Error (MSE) \t:", mse)
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mse))
# Out:
# Explained Variance (R^2) 	: 0.07619223326030067
# Mean Squared Error (MSE) 	: 6577242688.114611
# Root Mean Squared Error (RMSE) 	: 81100.20152943277

# %% [markdown]
# ### TotalBsmtSF

# %%
#a) Plot SalePrice against TotalBsmtSF using any appropriate bivariate plot to note the strong linear relationship.

houseData = pd.read_csv('train.csv')

salePrice = pd.DataFrame(houseData['SalePrice'])
totalBsmtSF = pd.DataFrame(houseData['TotalBsmtSF']) 

# Create a joint dataframe by concatenating the two variables
trainDF = pd.concat([totalBsmtSF, salePrice], axis = 1).reindex(totalBsmtSF.index)

# Jointplot of Total Train against HP Train
sb.jointplot(data = trainDF, x = "TotalBsmtSF", y = "SalePrice", height = 12)

# %%
#b) Print the correlation coefficient between these two variables to get a numerical evidence of the relationship.
print(trainDF.corr())
# Out:
#              TotalBsmtSF  SalePrice
# TotalBsmtSF     1.000000   0.613581
# SalePrice       0.613581   1.000000

# %%
#d) Partition the dataset houseData into two “random” portions : Train Data (1100 rows) and Test Data (360 rows).

# Split the Dataset into Train and Test
t_train, t_test, s_train, s_test = train_test_split(totalBsmtSF, salePrice, test_size = 360)

# %%
#e) Training : Fit a Linear Regression model on the Train Dataset to predict or estimate SalePrice using TotalBsmtArea.

# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(t_train, s_train)        # train the linear regression model

# Predict SalePrice values corresponding to TotalBsmtArea
s_train_pred = linreg.predict(t_train)
s_test_pred = linreg.predict(t_test)

# %%
#f) Print the coefficients of the Linear Regression model you just fit, and plot the regression line on a scatterplot.

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)

# Plot the Linear Regression line
f = plt.figure(figsize=(16, 8))
plt.scatter(t_train, s_train)
plt.scatter(t_train, s_train_pred, color = "r")
plt.show()
# Out:
# Intercept of Regression 	: b =  [67339.91810291]
# Coefficients of Regression 	: a =  [[107.4221318]]

# %%
#g) Print Explained Variance (R^2) and Mean Squared Error (MSE) on Train Data to check Goodness of Fit of model.

# Explained Variance (R^2)
print("Explained Variance (R^2) \t:", linreg.score(t_train, s_train))

mse = mean_sq_err(s_train, s_train_pred)
print("Mean Squared Error (MSE) \t:", mse)
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mse))
# Out:
# Explained Variance (R^2) 	: 0.3560153800026994
# Mean Squared Error (MSE) 	: 4201161445.2112
# Root Mean Squared Error (RMSE) 	: 64816.36710901962

# %%
#h) Predict SalePrice in case of Test Data using the Linear Regression model and the predictor variable TotalBsmtArea

# Predict SalePrice values corresponding to TotalBsmtArea
s_test_pred = linreg.predict(t_test)

# %%
#i) Plot the predictions on a Scatterplot of TotalBsmtSF and SalePrice in the Test Data to visualize model accuracy.

# Plot the Predictions
f = plt.figure(figsize=(16, 8))
plt.scatter(t_test, s_test, color = "green")
plt.scatter(t_test, s_test_pred, color = "red")
plt.show()

# %%
#j) Print the Mean Squared Error (MSE) on Test Data to check Goodness of Fit of model, compared to the Training.

# Explained Variance (R^2)
print("Explained Variance (R^2) \t:", linreg.score(t_test, s_test))

mse = mean_sq_err(s_test, s_test_pred)
print("Mean Squared Error (MSE) \t:", mse)
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mse))
# Out:
# Explained Variance (R^2) 	: 0.4468029706994451
# Mean Squared Error (MSE) 	: 3121798792.4463787
# Root Mean Squared Error (RMSE) 	: 55873.05963025811

# %% [markdown]
# ### GarageArea

# %%
#a) Plot SalePrice against GarageArea using any appropriate bivariate plot to note the strong linear relationship.

houseData = pd.read_csv('train.csv')

salePrice = pd.DataFrame(houseData['SalePrice'])
garageArea = pd.DataFrame(houseData['GarageArea']) 

# Create a joint dataframe by concatenating the two variables
trainDF = pd.concat([garageArea, salePrice], axis = 1).reindex(garageArea.index)

# Jointplot of Total Train against HP Train
sb.jointplot(data = trainDF, x = "GarageArea", y = "SalePrice", height = 12)

# %%
#b) Print the correlation coefficient between these two variables to get a numerical evidence of the relationship.
print(trainDF.corr())
# Out:
#             GarageArea  SalePrice
# GarageArea    1.000000   0.623431
# SalePrice     0.623431   1.000000

# %%
#d) Partition the dataset houseData into two “random” portions : Train Data (1100 rows) and Test Data (360 rows).

# Split the Dataset into Train and Test
g2_train, g2_test, s_train, s_test = train_test_split(garageArea, salePrice, test_size = 360)

# %%
#e) Training : Fit a Linear Regression model on the Train Dataset to predict or estimate SalePrice using GarageArea.

# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(g2_train, s_train)        # train the linear regression model

# Predict SalePrice values corresponding to GarageArea
s_train_pred = linreg.predict(g2_train)
s_test_pred = linreg.predict(g2_test)

# %%
#f) Print the coefficients of the Linear Regression model you just fit, and plot the regression line on a scatterplot.

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)

# Plot the Linear Regression line
f = plt.figure(figsize=(16, 8))
plt.scatter(g2_train, s_train)
plt.scatter(g2_train, s_train_pred, color = "r")
plt.show()
# Out:
# Intercept of Regression 	: b =  [72628.85928993]
# Coefficients of Regression 	: a =  [[228.76384493]]

# %%
#g) Print Explained Variance (R^2) and Mean Squared Error (MSE) on Train Data to check Goodness of Fit of model.

# Explained Variance (R^2)
print("Explained Variance (R^2) \t:", linreg.score(g2_train, s_train))

mse = mean_sq_err(s_train, s_train_pred)
print("Mean Squared Error (MSE) \t:", mse)
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mse))
# Out:
# Explained Variance (R^2) 	: 0.36476463425321126
# Mean Squared Error (MSE) 	: 4089082811.4595437
# Root Mean Squared Error (RMSE) 	: 63945.93662977769

# %%
#h) Predict SalePrice in case of Test Data using the Linear Regression model and the predictor variable GarageArea

# Predict SalePrice values corresponding to GarageArea
s_test_pred = linreg.predict(g2_test)

# %%
#i) Plot the predictions on a Scatterplot of GarageArea and SalePrice in the Test Data to visualize model accuracy.

# Plot the Predictions
f = plt.figure(figsize=(16, 8))
plt.scatter(g2_test, s_test, color = "green")
plt.scatter(g2_test, s_test_pred, color = "red")
plt.show()

# %%
#j) Print the Mean Squared Error (MSE) on Test Data to check Goodness of Fit of model, compared to the Training.

# Explained Variance (R^2)
print("Explained Variance (R^2) \t:", linreg.score(g2_test, s_test))

mse = mean_sq_err(s_test, s_test_pred)
print("Mean Squared Error (MSE) \t:", mse)
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mse))
# Out:
# Explained Variance (R^2) 	: 0.46776031076827074
# Mean Squared Error (MSE) 	: 3143548063.365183
# Root Mean Squared Error (RMSE) 	: 56067.3529191916

# %% [markdown]
# ## Question 3

# %% [markdown]
# #### Among the 4 variables' train and test data, GrLivArea has the highest explained variance and lowest mean squared error, with TotalBsmtArea and GarageArea having similar explained variance and mean squared area, and LotArea having the lowest explained variance and highest mean squared error. This shows that the model provided by GrLivArea is able to make a more accurate prediction of SalePrice. Along with visual inspection of the regression models, we can see that GrLivArea is the most accurate in predicting SalePrice and therefore the best model.
