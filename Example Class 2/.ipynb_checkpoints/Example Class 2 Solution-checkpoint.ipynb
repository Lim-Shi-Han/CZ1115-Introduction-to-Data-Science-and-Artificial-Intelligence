# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
sb.set()

# %%
#1(a) Import train.csv
train_data = pd.read_csv('train.csv', header = 0)
train_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#1(b) Data types
train_data.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
#1(c) Dataframe with integers only
integerColumns = train_data.select_dtypes('int64')
integerColumns.head()
# Out:
#    Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0   1          60     8450            7            5       2003          2003
# 1   2          20     9600            6            8       1976          1976
# 2   3          60    11250            7            5       2001          2002
# 3   4          70     9550            7            5       1915          1970
# 4   5          60    14260            8            5       2000          2000
#
#    BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  WoodDeckSF  OpenPorchSF  \
# 0         706           0        150  ...           0           61
# 1         978           0        284  ...         298            0
# 2         486           0        434  ...           0           42
# 3         216           0        540  ...           0           35
# 4         655           0        490  ...         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %%
integerColumns = integerColumns.drop(['MSSubClass','OverallQual','OverallCond','YearBuilt','YearRemodAdd','MoSold','YrSold'], axis = 1)
print(integerColumns)
# Out:
#         Id  LotArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  \
# 0        1     8450         706           0        150          856       856
# 1        2     9600         978           0        284         1262      1262
# 2        3    11250         486           0        434          920       920
# 3        4     9550         216           0        540          756       961
# 4        5    14260         655           0        490         1145      1145
# ...    ...      ...         ...         ...        ...          ...       ...
# 1455  1456     7917           0           0        953          953       953
# 1456  1457    13175         790         163        589         1542      2073
# 1457  1458     9042         275           0        877         1152      1188
# 1458  1459     9717          49        1029          0         1078      1078
# 1459  1460     9937         830         290        136         1256      1256
#
# ...

# %%
#2(a) Summary statistics of SalePrice
print(np.mean(train_data['SalePrice']))
print(np.median(train_data['SalePrice']))
print(np.percentile(train_data['SalePrice'], 25))
print(np.percentile(train_data['SalePrice'], 75))
train_data['SalePrice'].describe()
# Out:
# 180921.19589041095
# 163000.0
# 129975.0
# 214000.0
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
#2(b) Plots of SalePrice
f = plt.figure(figsize=(24, 12))
sb.boxplot(data = train_data['SalePrice'], orient = "h")
# Out:
# <AxesSubplot:>

# %%
f = plt.figure(figsize=(24, 12))
sb.histplot(data = train_data['SalePrice'])
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Count'>

# %%
f = plt.figure(figsize=(24, 12))
sb.violinplot(data = train_data['SalePrice'], orient = "h")
# Out:
# <AxesSubplot:>

# %%
#2(c)
train_data['LotArea'].describe()
# Out:
# count      1460.000000
# mean      10516.828082
# std        9981.264932
# min        1300.000000
# 25%        7553.500000
# 50%        9478.500000
# 75%       11601.500000
# max      215245.000000
# Name: LotArea, dtype: float64

# %%
#2(d) Plots of SalePrice
f = plt.figure(figsize=(24, 12))
sb.boxplot(data = train_data['LotArea'], orient = "h")
# Out:
# <AxesSubplot:>

# %%
f = plt.figure(figsize=(24, 12))
sb.histplot(data = train_data['LotArea'])
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='Count'>

# %%
f = plt.figure(figsize=(24, 12))
sb.violinplot(data = train_data['SalePrice'], orient = "h")
# Out:
# <AxesSubplot:>

# %%
#2(e)

f, axes = plt.subplots(2, 3, figsize=(20, 30))

SalePrice = train_data['SalePrice']
LotArea = train_data['LotArea']

# Plot the basic uni-variate figures for SalePrice
sb.boxplot(data = SalePrice, orient = "h", ax = axes[0,0])
sb.histplot(data = SalePrice, ax = axes[0,1])
sb.violinplot(data = SalePrice, orient = "h", ax = axes[0,2])

# Plot the basic uni-variate figures for LotArea
sb.boxplot(data = LotArea, orient = "h", ax = axes[1,0])
sb.histplot(data = LotArea, ax = axes[1,1])
sb.violinplot(data = LotArea, orient = "h", ax = axes[1,2])
# Out:
# <AxesSubplot:>

# %%
# Create a joint dataframe by concatenating the two variables
jointDF = pd.concat([LotArea, SalePrice], axis = 1).reindex(LotArea.index)

# Draw jointplot of the two variables in the joined dataframe
sb.jointplot(data = jointDF, x = "LotArea", y = "SalePrice", height = 12)

# %%
sb.heatmap(jointDF.corr(), vmin = -1, vmax = 1, annot = True, fmt=".2f")
# Out:
# <AxesSubplot:>
