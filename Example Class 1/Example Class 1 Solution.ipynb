# %%
# Basic Libraries
import numpy as np
import pandas as pd

# %%
#1(a) Import train.csv
train_data = pd.read_csv('train.csv')
train_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#1(b) Shape of dataset 
print("Data type : ", type(train_data))
print("Data dims : ", train_data.shape)
# Out:
# Data type :  <class 'pandas.core.frame.DataFrame'>
# Data dims :  (1460, 81)

# %%
#1(c) Data types
train_data.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
#1(d) .info()
print(train_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
#1(e) .describe()
train_data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
#2(a) Import Wikpedia page
olympics_data = pd.read_html('https://en.wikipedia.org/wiki/2016_Summer_Olympics_medal_table')
olympics_data[2].head()
# Out:
#                                          Ruling date  \
# 0  List of official changes in medal standings (d...
# 1                                     18 August 2016
# 2                                     18 August 2016
# 3  List of official changes in medal standings (a...
# 4                                    8 December 2016
#
#                                          Sport/Event  \
# 0  List of official changes in medal standings (d...
# 1                           WeightliftingMen's 69 kg
# 2                           WeightliftingMen's 69 kg
# 3  List of official changes in medal standings (a...
# 4                           WeightliftingMen's 85 kg
#
#                                        Athlete (NOC)  \
# 0  List of official changes in medal standings (d...
# 1                            Izzat Artykov (KGZ) DSQ
# 2                         Luis Javier Mosquera (COL)
# 3  List of official changes in medal standings (a...
# ...

# %%
#2(b) No. of tables
print("Data type : ", type(olympics_data))
print("HTML tables : ", len(olympics_data))
# Out:
# Data type :  <class 'list'>
# HTML tables :  6

# %%
#1(c) Find out the actual table
for i in range(6):
    print("Table", i)
    print(olympics_data[i].head())
    print("\n")
    
#Table 1(Second table)
# Out:
# Table 0
#                                                    0
# 0                                Part of a series on
# 1  2016 Summer Olympics Bid process (bid details)...
#
#
# Table 1
#   Rank                  NOC  Gold  Silver  Bronze  Total
# 0    1  United States (USA)    46      37      38    121
# 1    2  Great Britain (GBR)    27      23      17     67
# 2    3          China (CHN)    26      18      26     70
# 3    4         Russia (RUS)    19      17      20     56
# 4    5        Germany (GER)    17      10      15     42
#
#
# Table 2
#                                          Ruling date  \
# 0  List of official changes in medal standings (d...
# 1                                     18 August 2016
# 2                                     18 August 2016
# 3  List of official changes in medal standings (a...
# 4                                    8 December 2016
#
#                                          Sport/Event  \
# ...

# %%
#1(d) New Pandas dataframe
medalTable = pd.DataFrame(olympics_data[1])
medalTable.head()
# Out:
#   Rank                  NOC  Gold  Silver  Bronze  Total
# 0    1  United States (USA)    46      37      38    121
# 1    2  Great Britain (GBR)    27      23      17     67
# 2    3          China (CHN)    26      18      26     70
# 3    4         Russia (RUS)    19      17      20     56
# 4    5        Germany (GER)    17      10      15     42

# %%
#1(e) Top 20 countries table
'''
top20 = medalTable.iloc[0]
for i in range(1, 20):
    temp = medalTable.iloc[i]
    top20 = pd.concat([top20, temp], axis = 1).reindex(top20.index)
top20 = top20.transpose()
top20
'''
top20 = medalTable.head(20)
top20
# Out:
#    Rank                  NOC  Gold  Silver  Bronze  Total
# 0     1  United States (USA)    46      37      38    121
# 1     2  Great Britain (GBR)    27      23      17     67
# 2     3          China (CHN)    26      18      26     70
# 3     4         Russia (RUS)    19      17      20     56
# 4     5        Germany (GER)    17      10      15     42
# 5     6          Japan (JPN)    12       8      21     41
# 6     7         France (FRA)    10      18      14     42
# 7     8    South Korea (KOR)     9       3       9     21
# 8     9          Italy (ITA)     8      12       8     28
# 9    10      Australia (AUS)     8      11      10     29
# 10   11    Netherlands (NED)     8       7       4     19
# 11   12        Hungary (HUN)     8       3       4     15
# 12   13        Brazil (BRA)*     7       6       6     19
# 13   14          Spain (ESP)     7       4       6     17
# 14   15          Kenya (KEN)     6       6       1     13
# ...

# %%
#Bonus problem A
income_data = pd.read_html('https://archive.ics.uci.edu/ml/datasets/Census+Income')
print("Len:", len(income_data))
for i in range(5):
    print("Table", i)
    print(income_data[i])
    print("\n")
    print(income_data[i].shape())
# Out:
# Len: 5
# Table 0
#                                                    0  \
# 0  Center for Machine Learning and Intelligent Sy...
#
#                                                    1
# 0  About Citation Policy Donate a Data Set Contac...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-4231ebb5d6f3> in <module>
#       6     print(income_data[i])
#       7     print("\n")
# ----> 8     print(income_data[i].shape())
#
# TypeError: 'tuple' object is not callable

# %%
#Bonus Question B

dic = {}

for year in (2000, 2004, 2006, 2008, 2012, 2016):
    html = 'https://en.wikipedia.org/wiki/'+str(year)+'_Summer_Olympics_medal_table'
    table = html[i]
    dic{'Year ' + str(year)} = table

new_dic = {}
for key in dic:
    data = 
'''
for i in range(5):
    year = 2000 + 4 * i
    olympics_tally_html = 'https://en.wikipedia.org/wiki/'+str(year)+'_Summer_Olympics_medal_table'
    olympics_tally = pd.read_html(olympics_tally_html)
    print("Year", year, "\n\n", olympics_tally[1].head(20), "\n")
'''
